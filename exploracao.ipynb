# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/williamdumaszak/Downloads/INFLUD19-26-06-2025.csv', sep=';')
df.describe()
# Out:
# /var/folders/l4/czj91mf11ts2q7q0s5d215kr0000gn/T/ipykernel_54078/2670184794.py:1: DtypeWarning: Columns (92,94,115,117,118,119,121,122,129,130,144,147,150,155,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/williamdumaszak/Downloads/INFLUD19-26-06-2025.csv', sep=';')
#          NU_NOTIFIC       SEM_NOT       SEM_PRI    CO_REGIONA     CO_MUN_NOT  \
# count  4.896100e+04  48961.000000  48961.000000  44025.000000   48919.000000
# mean   3.988611e+11     25.216438     24.674047   1671.653856  351219.158752
# std    1.613231e+12     11.459829     11.530126    914.353929   96580.415434
# min    3.154782e+11      1.000000      1.000000   1331.000000  110001.000000
# 25%    3.155734e+11     17.000000     17.000000   1353.000000  310620.000000
# 50%    3.156146e+11     24.000000     23.000000   1449.000000  354390.000000
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
print(df.columns)
# Out:
# Index(['NU_NOTIFIC', 'DT_NOTIFIC', 'SEM_NOT', 'DT_SIN_PRI', 'SEM_PRI',
#        'SG_UF_NOT', 'ID_REGIONA', 'CO_REGIONA', 'ID_MUNICIP', 'CO_MUN_NOT',
#        ...
#        'VG_OMS', 'VG_OMSOUT', 'VG_LIN', 'VG_MET', 'VG_METOUT', 'VG_DTRES',
#        'VG_ENC', 'VG_REINF', 'VG_CODEST', 'REINF'],
#       dtype='object', length=194)

# %%
df=list(df.columns)

# %%
colunas=('NU_NOTIFIC','DT_NOTIFIC','EVOLUCAO','UTI','VACINA_COV')

# %%
df.filter(colunas)
# Out:
#            NU_NOTIFIC  DT_NOTIFIC  EVOLUCAO  UTI  VACINA_COV
# 0        315478195042  2019-01-10       1.0  2.0         NaN
# 1        315478195276  2019-01-03       1.0  1.0         NaN
# 2        315478207219  2019-01-02       1.0  2.0         NaN
# 3        315478211086  2019-01-10       1.0  1.0         NaN
# 4        315478212765  2019-01-11       2.0  9.0         NaN
# ...               ...         ...       ...  ...         ...
# 48956  31692547426126  2023-08-20       1.0  2.0         2.0
# 48957  31706621109902  2019-05-13       2.0  1.0         2.0
# 48958  31706621464126  2019-06-11       2.0  NaN         2.0
# 48959  31709922959685  2019-10-30       1.0  NaN         2.0
# 48960  31709925127509  2019-06-01       2.0  2.0         2.0
#
# [48961 rows x 5 columns]

# %%
df.describe()
# Out:
#          NU_NOTIFIC        SEM_NOT        SEM_PRI     CO_REGIONA  \
# count  2.564010e+05  256401.000000  256401.000000  223789.000000
# mean   3.174884e+13      21.814931      20.905979    1591.776843
# std    5.305103e+09       8.777088       8.793360     712.170606
# min    3.173545e+13       1.000000       1.000000    1331.000000
# 25%    3.174559e+13      16.000000      15.000000    1354.000000
# 50%    3.174913e+13      22.000000      21.000000    1449.000000
# 75%    3.175267e+13      28.000000      27.000000    1550.000000
# max    3.175851e+13      39.000000      39.000000    6256.000000
#
#           CO_MUN_NOT     NU_IDADE_N       TP_IDADE     CS_GESTANT  \
# count  256401.000000  256401.000000  256401.000000  256401.000000
# mean   348145.438914      30.100608       2.705976       5.825984
# std     95228.748605      32.459364       0.489827       0.640847
# min    110002.000000      -1.000000       1.000000       0.000000
# ...

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached matplotlib-3.10.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# ...
#   Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached tornado-6.4.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (2.5 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (112 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...

# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
from pathlib import Path

class ETL:
    def __init__(self):
        self.columns = [
            # substitua pelas colunas relevantes
            "DT_NOTIFIC", "CS_SEXO", "NU_IDADE_N", "SG_UF", "EVOLUCAO"
        ]
        self.output_path = Path("data/processed/srag_clean.parquet")

    def extract_api(self) -> pd.DataFrame:
        base_url = "https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2025/INFLUD25-{date}.csv"

        # 1. Carrega o parquet existente (se existir)
        if self.output_path.exists():
            df_final = pd.read_parquet(self.output_path, engine="pyarrow")
        else:
            df_final = pd.DataFrame(columns=self.columns)

        # 2. Baixa dados novos (testa últimos 30 dias)
        today = datetime.now()
        new_dataframes = []

        for i in range(30):
            dt = today - timedelta(days=i)
            date_str = dt.strftime("%d-%m-%Y")
            url = base_url.format(date=date_str)
            r = requests.head(url)
            if r.status_code == 200:
                print(f"Baixando dados de {date_str}...")
                df = pd.read_csv(url, sep=";", encoding="latin1", on_bad_lines="skip")
                df_filter = df.filter(self.columns, axis=1)
                df_filter.drop_duplicates(inplace=True)

                # Adiciona apenas se tiver linhas novas
                new_dataframes.append(df_filter)

        if not new_dataframes:
            print("Nenhum novo arquivo disponível nas últimas 30 datas.")
            return df_final

        # 3. Concatena tudo
        df_new = pd.concat(new_dataframes, ignore_index=True)
        
        # 4. Remove registros já existentes
        if not df_final.empty:
            before = len(df_new)
            df_new = pd.concat([df_final, df_new]).drop_duplicates(subset=self.columns)
            after = len(df_new)
            print(f"Foram adicionadas {after - len(df_final)} novas linhas (de {before} baixadas).")
        else:
            print(f"Arquivo inicial criado com {len(df_new)} registros.")
        
        # 5. Salva parquet atualizado
        df_new.to_parquet(self.output_path, engine="pyarrow", index=False)
        print(f"Parquet atualizado salvo em: {self.output_path}")

        return df_new

# %%
# Projetos internos
from src.etl import ETL
from src.metrics import METRICS
from src.viz import VIZ

# %%
#import
import pandas as pd
from pathlib import Path
import requests
from datetime import datetime, timedelta

class ETL:
    #responsável por buscar os dados referentes aos casos na API do opendatasus
    def __init__(self):
        self.columns=('NU_NOTIFIC','DT_NOTIFIC','EVOLUCAO','UTI','VACINA_COV')
        self.today = datetime.now()

    def extract_api_latest(self) -> pd.DataFrame:

        df_salvo= pd.read_parquet("data/processed/srag_clean.parquet", engine="pyarrow")
        df_salvo["DT_NOTIFIC"] = pd.to_datetime(df_salvo["DT_NOTIFIC"], errors="coerce")
        if (df_salvo["DT_NOTIFIC"].dt.strftime("%Y-%m-%d") == (self.today - timedelta(days=1)).strftime("%Y-%m-%d")).any():
            return df_salvo
        else:
            base_url = "https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2025/INFLUD25-{date}.csv"
            
            # testa os últimos 30 dias
            for i in range(30):
                dt = self.today - timedelta(days=i)
                date_str = dt.strftime("%d-%m-%Y")
                url = base_url.format(date=date_str)
                r = requests.head(url)
                if r.status_code == 200:
                    df = pd.read_csv(
                        url,
                        sep=";",
                        encoding="latin1",
                        on_bad_lines="skip"
                    )
                    #filtra e deixa apenas colunas relevantes
                    df_filter = df.filter(self.columns)
                    df_filter.drop_duplicates(inplace=True)

                    df_filter = pd.concat([df_salvo, df_filter], ignore_index=True).drop_duplicates(subset=self.columns)
                    df_filter.drop_duplicates(inplace=True)
                    df_filter["DT_NOTIFIC"] = pd.to_datetime(df_filter["DT_NOTIFIC"], errors="coerce")
                    df_filter.to_parquet("data/processed/srag_clean.parquet", engine="pyarrow", index=False)
                    df_final=df_filter
                    return df_final

# %%
import pandas as pd
from pathlib import Path
import requests
from datetime import datetime, timedelta

# %%
#estancia o ETL e extrai os dados mais recentes
etl=ETL()
dados=etl.extract_api_latest()

# --- Funções utilitárias ---

#passa base de dados e extrai as metricas

df = dados
growth = growth_rate(df)
mortality = METRICS.mortality_rate(df)
uti = METRICS.uti_rate(df)
vacc = METRICS.vaccination_rate(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       5 # --- Funções utilitárias ---
#       6
#       7 #passa base de dados e extrai as metricas
#       9 df = dados
# ---> 10 growth = growth_rate(df)
#      11 mortality = METRICS.mortality_rate(df)
#      12 uti = METRICS.uti_rate(df)
#
# NameError: name 'growth_rate' is not defined

# %%
df_sorted = etl.sort_values(by='DT_NOTIFIC', ascending=True)

print(df_sorted)
# Out:
#              NU_NOTIFIC DT_NOTIFIC  EVOLUCAO  UTI  VACINA_COV
# 1188       315504989464 2018-12-30       1.0  1.0         2.0
# 1321       315506035657 2018-12-30       1.0  1.0         2.0
# 19         315478273135 2018-12-30       1.0  2.0         2.0
# 4024       315531747731 2019-01-01       1.0  2.0         2.0
# 375        315484268300 2019-01-01       2.0  1.0         2.0
# ...                 ...        ...       ...  ...         ...
# 4365926  31758479466398 2025-09-21       NaN  1.0         2.0
# 4365927  31758480095066 2025-09-21       NaN  NaN         1.0
# 4365929  31758480530350 2025-09-21       NaN  1.0         2.0
# 4365906  31758457713006 2025-09-21       NaN  2.0         2.0
# 4365967  31758514429630 2025-09-21       NaN  NaN         1.0
#
# [4365968 rows x 5 columns]

# %%
print(vacc)
# Out:
# 0.30347963562253283

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta

# %%
lookback_days=7
df['DT_NOTIFIC'] = pd.to_datetime(df['DT_NOTIFIC'], errors='coerce')
today = pd.Timestamp.now().normalize()
cur_start = today - pd.Timedelta(days=lookback_days)
prev_start = cur_start - pd.Timedelta(days=lookback_days)
cur = df[(df['DT_NOTIFIC'] >= cur_start) & (df['DT_NOTIFIC'] < today)].shape[0]
prev = df[(df['DT_NOTIFIC'] >= prev_start) & (df['DT_NOTIFIC'] < cur_start)].shape[0]

print(today, cur_start, prev_start)
(cur - prev) / prev if prev > 0 else np.nan
# Out:
# 2025-10-06 00:00:00 2025-09-29 00:00:00 2025-09-22 00:00:00
# nan

# %%
print(cur, prev)
# Out:
# 0 0

# %%
from src.etl import ETL

import pandas as pd

# %%
etl=ETL()
dados=etl.extract_api_latest()
# Out:
# /Users/williamdumaszak/GitHub/gen-ai-health-poc/src/etl.py:29: DtypeWarning: Columns (14,92,94,185,186,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df_salvo= pd.read_parquet("data/processed/srag_clean.parquet", engine="pyarrow")

# %%
df_salvo.tail()
# Out:
#              NU_NOTIFIC DT_NOTIFIC  EVOLUCAO  UTI  VACINA_COV
# 4653750  31759708032675 2025-10-05       NaN  2.0         2.0
# 4653751  31759708640962 2025-10-05       NaN  2.0         2.0
# 4653752  31759715834473 2025-10-05       NaN  1.0         1.0
# 4653753  31759722690545 2025-10-05       NaN  NaN         2.0
# 4653754  31759724191654 2025-10-05       NaN  NaN         1.0
